# %% [markdown]
# # Import modules

# %%
# Code by: O, Wani, 2021

import numpy as np                      # for scientific computing and array analysis
import pandas as pd                     # for working with data strcutures
from scipy.integrate import odeint      # for working with ordinary differential equations
import scipy.stats as stats

# displaying plots inline 
# %matplotlib inline                      

import matplotlib.pyplot as plt         # for 2D plotting

import math                             # for mathematical functions defined by the C standard
import statsmodels.api as sm            # for autocorrelation function
import os                               # for interacting with the operating system
import seaborn as sns                   # for 3D plotting
import astroabc                         # for inference of SDE parameters
import ipynb                            # for importing ipynb files as modules
import random                           # for pseudo-random number generators
import timeit

os.chdir('/home/owani/Office/Berkeley/Scripts/sde') # set working directory

# %%
from ipynb.fs.full.import_data import get_data, get_station_name # Import data

# import helper functions
from CatchmentBasics import *
from Data_analysis_helper import *

# %% [markdown]
# ### Selected catchments

# %%
selected_lst = ['DryCreek','SagehenCreek','AndrewsForest','BonanzaCreek','CaliforniaCurrentEcosystem',
                'HubbardBrook','Kellogg','KonzaPrairie','Sevilleta','Reynolds']

# %%
### Trim table to the same record length

# Use the fucntion trim_short you can trim all the records based on the shorted one
# Discharge and ALL the ppt record length
# The trimmed table is ready to use
trimmed_table = {}

for ws in selected_lst:
    #print("\n"+ws)
    
    data = pd.read_csv('data/5_'+ws+'_final_cleaned.csv', index_col = 'DateTime')
    dis_stn = main_str_dic[ws][1]
    dis_ppt_data = subset_table(table=data,dis_stn=dis_stn,met_stn=[],acq_vars=['Discharge','Precipitation'])
    trimmed_table[ws] = trim_short(dis_ppt_data)
    #print('report data length for trimmed table')
    #report_length(trimmed_table)
# Out:
# LG_Discharge starts at 1999-02-06 ends at 2019-12-31
# BRW_Precipitation starts at 2011-01-01 ends at 2019-12-31
# LDP_Precipitation starts at 2007-01-01 ends at 2019-11-17
# SCR_Precipitation starts at 2010-01-01 ends at 2018-10-15
# TL_Precipitation starts at 1999-02-06 ends at 2018-10-09
# LW_Precipitation starts at 1999-02-06 ends at 2018-10-09
# The lastest starting date is 2011-01-01
# The earliest ending date is 2018-10-09
# Table start from 2011-01-01 to 2018-10-09
# Sagehen_Discharge starts at 1956-10-01 ends at 2020-12-31
# 539lvl1B_Precipitation starts at 1978-10-01 ends at 2017-09-30
# 539lvl2_Precipitation starts at 1978-10-01 ends at 2017-09-30
# 540lvlB_Precipitation starts at 1980-10-01 ends at 2017-09-30
# 540lvl2_Precipitation starts at 1980-10-01 ends at 2017-09-30
# 541lvlB_Precipitation starts at 1978-10-01 ends at 2017-09-30
# 541lvl2_Precipitation starts at 1978-10-01 ends at 2017-09-30
# wrcclvl1B_Precipitation starts at 1956-10-01 ends at 2007-06-30
# wrcclvl2_Precipitation starts at 1956-10-01 ends at 1997-02-03
# The lastest starting date is 1980-10-01
# The earliest ending date is 1997-02-03
# Table start from 1980-10-01 to 1997-02-03
# GSLOOK_Discharge starts at 1957-10-01 ends at 2019-08-07
# CENMET_Precipitation starts at 1995-08-23 ends at 2018-09-30
# CS2MET_Precipitation starts at 1957-10-01 ends at 2018-09-30
# H15MET_Precipitation starts at 1957-10-01 ends at 2019-02-12
# PRIMET_Precipitation starts at 1979-03-06 ends at 2018-09-30
# UPLMET_Precipitation starts at 1994-10-01 ends at 2019-03-17
# VANMET_Precipitation starts at 1987-06-16 ends at 1996-02-19
# VARMET_Precipitation starts at 1998-11-14 ends at 2018-09-30
# The lastest starting date is 1998-11-14
# The earliest ending date is 1996-02-19
# Table start from 1998-11-14 to 1996-02-19
# C4_Discharge starts at 1989-06-15 ends at 2018-08-21
# FP1A_Precipitation_tipbuck starts at 2009-05-02 ends at 2016-11-02
# FP2A_Precipitation_tipbuck starts at 2002-07-31 ends at 2016-09-21
# FP3A_Precipitation_tipbuck starts at 2009-05-02 ends at 2016-10-02
# FP4A_Precipitation_tipbuck starts at 2002-08-16 ends at 2016-10-02
# FP5A_Precipitation_tipbuck starts at 2009-05-03 ends at 2016-10-02
# FP5C_Precipitation_tipbuck starts at 2010-09-22 ends at 2016-10-31
# LTER1_Precipitation_tipbuck starts at 1989-05-22 ends at 2015-12-31
# LTER2_Precipitation_tipbuck starts at 2008-12-21 ends at 2016-12-31
# UP1A_Precipitation_tipbuck starts at 2002-06-25 ends at 2016-10-05
# UP2A_Precipitation_tipbuck starts at 2002-06-26 ends at 2016-09-19
# UP3A_Precipitation_tipbuck starts at 2002-06-28 ends at 2016-09-19
# UP4A_Precipitation_tipbuck starts at 2006-05-02 ends at 2016-09-19
# CARSNOW_Precipitation_tipbuck starts at 2006-10-04 ends at 2010-12-31
# CPEAK_Precipitation_tipbuck starts at 1998-08-05 ends at 2016-12-31
# CRREL_Precipitation_tipbuck starts at 2007-07-18 ends at 2016-10-05
# HR1A_Precipitation_tipbuck starts at 2001-09-10 ends at 2016-10-05
# LTER1_Precipitation_weighbuck starts at 1989-05-22 ends at 2015-12-31
# LTER2_Precipitation_weighbuck starts at 2008-12-21 ends at 2016-12-31
# CARSNOW_Precipitation_weighbuck starts at 2007-07-18 ends at 2016-12-31
# CPEAK_Precipitation_weighbuck starts at 1998-08-12 ends at 2016-12-31
# The lastest starting date is 2010-09-22
# The earliest ending date is 2010-12-31
# Table start from 2010-09-22 to 2010-12-31
# FashionValley_Discharge starts at 1982-01-18 ends at 2017-04-12
# Lindberch_Precipitation starts at 1939-07-01 ends at 2017-04-12
# The lastest starting date is 1982-01-18
# The earliest ending date is 2017-04-12
# Table start from 1982-01-18 to 2017-04-12
# WS7_Discharge starts at 1956-01-01 ends at 2014-12-31
# WS1_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS2_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS3_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS4_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS5_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS6_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS7_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS8_Precipitation starts at 1956-01-01 ends at 2014-12-31
# WS9_Precipitation starts at 1995-01-01 ends at 2014-12-31
# The lastest starting date is 1995-01-01
# The earliest ending date is 2014-12-31
# Table start from 1995-01-01 to 2014-12-31
# KBS096_Discharge starts at 1964-10-01 ends at 2019-06-12
# KBS017_Precipitation starts at 1964-10-01 ends at 2012-08-31
# KBS064_Precipitation starts at 1964-10-01 ends at 1987-04-30
# KBS002_Precipitation starts at 1988-01-01 ends at 2019-06-12
# The lastest starting date is 1988-01-01
# The earliest ending date is 1987-04-30
# Table start from 1988-01-01 to 1987-04-30
# KingsRiver_Discharge starts at 1985-06-14 ends at 2019-12-31
# HQ01_Precipitation starts at 1985-06-14 ends at 2019-12-31
# The lastest starting date is 1985-06-14
# The earliest ending date is 2019-12-31
# Table start from 1985-06-14 to 2019-12-31
# PECOS_Discharge starts at 1988-01-01 ends at 2015-12-31
# Station1_Precipitation starts at 1992-01-01 ends at 2015-12-31
# Station40_Precipitation starts at 1988-01-01 ends at 2015-12-31
# Station41_Precipitation starts at 1989-01-01 ends at 2015-12-31
# Station42_Precipitation starts at 1989-01-01 ends at 2015-12-31
# Station43_Precipitation starts at 1989-01-01 ends at 2015-12-31
# Station44_Precipitation starts at 1989-01-01 ends at 2015-12-31
# Station45_Precipitation starts at 1990-01-01 ends at 2015-12-31
# Station46_Precipitation starts at 1990-01-01 ends at 1997-12-31
# Station47_Precipitation starts at 1991-01-01 ends at 1996-12-31
# Station48_Precipitation starts at 1998-01-01 ends at 2015-12-31
# Station49_Precipitation starts at 1999-01-01 ends at 2015-12-31
# Station50_Precipitation starts at 2002-01-01 ends at 2015-12-31
# The lastest starting date is 2002-01-01
# The earliest ending date is 1996-12-31
# Table start from 2002-01-01 to 1996-12-31
# 036_Discharge starts at 1963-01-01 ends at 2014-12-31
# 012_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 031_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 049_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 057_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 076_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 095b_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 098c_Precipitation starts at 1972-01-01 ends at 2014-12-31
# 116c_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 124_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 125_Precipitation starts at 2002-06-26 ends at 2014-12-31
# 127_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 13803_Precipitation starts at 1983-10-13 ends at 2014-12-31
# 138j10_Precipitation starts at 1983-10-08 ends at 2014-12-31
# 144_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 145_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 147_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 155_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 163_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 167_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 174_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 176_Precipitation starts at 1963-01-01 ends at 2014-12-31
# rmsp3_Precipitation starts at 1963-01-01 ends at 2014-12-31
# 138121_Precipitation starts at 2003-07-16 ends at 2014-12-31
# 166b_Precipitation starts at 2003-12-31 ends at 2013-07-10
# The lastest starting date is 2003-12-31
# The earliest ending date is 2013-07-10
# Table start from 2003-12-31 to 2013-07-10

# %%
trimmed_table['HubbardBrook'] # check how it looks
# Out:
#             WS7_Discharge  WS1_Precipitation  WS2_Precipitation  \
# DateTime
# 1995-01-01      11.190825                2.9                3.0
# 1995-01-02      10.384475                8.0                8.2
# 1995-01-03       9.636683                0.4                0.3
# 1995-01-04       8.919075                1.1                1.2
# 1995-01-05       8.182850                0.5                0.4
# ...                   ...                ...                ...
# 2014-12-27      36.982848                0.0                0.0
# 2014-12-28      43.946908               11.1               11.3
# 2014-12-29      35.914143                0.0                0.0
# 2014-12-30      21.862031                0.0                0.0
# 2014-12-31      15.703057                0.0                0.0
#
#             WS3_Precipitation  WS4_Precipitation  WS5_Precipitation  \
# DateTime
# 1995-01-01                3.2                3.0                3.3
# 1995-01-02                8.5                8.4                8.9
# 1995-01-03                0.3                0.4                0.3
# 1995-01-04                1.2                1.0                1.6
# 1995-01-05                0.4                0.5                0.5
# ...                       ...                ...                ...
# 2014-12-27                0.0                0.0                0.0
# 2014-12-28               11.6               10.9               11.1
# 2014-12-29                0.0                0.0                0.0
# 2014-12-30                0.0                0.0                0.0
# 2014-12-31                0.0                0.0                0.0
#
#             WS6_Precipitation  WS7_Precipitation  WS8_Precipitation  \
# DateTime
# 1995-01-01                3.4                2.0                2.0
# 1995-01-02                9.2               11.4               10.1
# 1995-01-03                0.3                0.5                0.5
# 1995-01-04                2.1                0.6                0.7
# 1995-01-05                0.6                0.3                0.4
# ...                       ...                ...                ...
# 2014-12-27                0.0                0.0                0.0
# 2014-12-28               11.0                7.5                7.6
# 2014-12-29                0.0                0.0                0.0
# 2014-12-30                0.0                0.0                0.0
# 2014-12-31                0.0                0.0                0.0
#
#             WS9_Precipitation
# DateTime
# 1995-01-01                1.9
# 1995-01-02               10.4
# 1995-01-03                0.5
# 1995-01-04                0.8
# 1995-01-05                0.4
# ...                       ...
# 2014-12-27                0.0
# 2014-12-28                8.3
# 2014-12-29                0.0
# 2014-12-30                0.0
# 2014-12-31                0.0
#
# [7305 rows x 10 columns]

# %% [markdown]
# # HJ Andrews

# %%
# load time series of rainfall, discharge, temperature and Snow Water Equivalent. 

rain = np.array(get_data(4,['Precipitation']).loc['2005-1-1':'2015-1-1'].mean(axis=1))[0:3000]
discharge = np.asarray(get_data(4,['Discharge']).loc['2005-1-1':'2015-1-1'][0:3000]['GSLOOK_Discharge'])
temp = get_data(4,['AirTemperature']).loc['2005-1-1':'2015-1-1'][0:3000]['VANMET_AirTemperature_50cm']
temp[temp<0]=0
swe = get_data(4,['SWE']).loc['2005-1-1':'2015-1-1'][0:3000]['VANMET_SWE']
sweb = swe/np.amax(swe)
# Out:
# HJAndrews
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'Snowmelt', 'VaporPressure', 'SoilTemperature', 'SoilMoisture']
# HJAndrews
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'Snowmelt', 'VaporPressure', 'SoilTemperature', 'SoilMoisture']
# HJAndrews
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'Snowmelt', 'VaporPressure', 'SoilTemperature', 'SoilMoisture']
# HJAndrews
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'Snowmelt', 'VaporPressure', 'SoilTemperature', 'SoilMoisture']

# %%
# Bonanza
# load time series of rainfall, discharge, temperature and Snow Water Equivalent. 

rain = np.array(get_data(6,['Precipitation']).loc['2010-1-1':'2015-1-1'][0:1400]['LTER1_Precipitation_tipbuck'])
discharge = np.asarray(get_data(6,['Discharge']).loc['2010-1-1':'2015-1-1'][0:1400]['C4_Discharge'])
temp = get_data(6,['AirTemperature']).loc['2010-1-1':'2015-1-1'][0:1400]['3AC_AirTemperature_log']
temp[temp<0]=0
swe = get_data(6,['SWE']).loc['2010-1-1':'2015-1-1'][0:1400]['LTER1_SWE'] # no SWE
sweb = swe/np.amax(swe)
# Out:
# Bonanza
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'VaporPressure', 'SoilMoisture', 'SoilTemperature']
# Bonanza
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'VaporPressure', 'SoilMoisture', 'SoilTemperature']
# Bonanza
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'VaporPressure', 'SoilMoisture', 'SoilTemperature']
# Bonanza
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SWE', 'SnowDepth', 'VaporPressure', 'SoilMoisture', 'SoilTemperature']

# %%
# Kellog
# load time series of rainfall, discharge, temperature and Snow Water Equivalent. 

rain =  np.asarray(get_data(15,['Precipitation']).loc['2005-1-1':'2015-1-1'][0:3000]['KBS002_Precipitation'])
discharge = np.asarray(get_data(15,['Discharge']).loc['2005-1-1':'2015-1-1'][0:3000]['KBS096_Discharge'])
# Out:
# Kellogg
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SnowDepth']
# Kellogg
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed', 'SnowDepth']

# %%
# KonzaPrairie
# load time series of rainfall, discharge, temperature and Snow Water Equivalent. 

rain =  np.asarray(get_data(16,['Precipitation']).loc['2005-1-1':'2015-1-1'][0:3000]['HQ01_Precipitation'])
discharge = np.asarray(get_data(16,['Discharge']).loc['2005-1-1':'2015-1-1'][0:3000]['KingsRiver_Discharge'])
# Out:
# KonzaPrairie
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed']
# KonzaPrairie
# Hydrometeorological variables in this watershed are:
# ['Discharge', 'Precipitation', 'AirTemperature', 'SolarRadiation', 'RelativeHumidity', 'WindDirection', 'WindSpeed']

# %% [markdown]
# # Define SDE

# %%
random.seed(10)

# Detailed error description; includes SWEB
# def sde(par):
#     x = np.zeros(n)
#     for i in range(n - 1):
#         x[i + 1] = x[i] -1/par[0]*x[i]*dt + 1*rain[i]*dt + par[1]*sweb[i]*temp[i]*dt + \
#         1*(np.sqrt(par[3])*x[i]+np.sqrt(par[4])*rain[i])*np.random.normal(0,np.sqrt(dt),1)+ \
#         np.sqrt(par[5])*np.random.lognormal(0,np.sqrt(dt),1)
#     return (1/par[0]*par[2]*x)

def sde(par):
    x = np.zeros(n)
    for i in range(n - 1):
        x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
    return (par[0]*(1/par[1])*x)

# %%
dt = 1  # Time step.
T = 1500.  # Total time.
n = int(T / dt)  # Number of time steps.
t = np.linspace(0., T, n)  # Vector of times.

par = [6000,0.5,0.0005,0.0005]

data1 = sde(par)  # test model
plt.plot(discharge[0:1500])
plt.plot(data1)

# %%
def dist_metric(d,x):
    return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
dist_metric(data1, discharge[0:1500])
# Out:
# 1.211242088988871

# %%
#HJA priors =  [('uniform', [20000, 400000]),('uniform', [0.01,2]),('uniform', [0.005,0.06]),('uniform', [0.001,0.04])] HJ Andrews
#kellogg priors =  [('uniform', [350, 530]),('uniform', [0.01,2]),('uniform', [0.0001,0.01]),('uniform', [0.0001,0.05])]
priors =  [('uniform', [2000, 4000]),('uniform', [0.01,2]),('uniform', [0.0001,0.005]),('uniform', [0.0001,0.01])]

# %%
prop={'dfunc':dist_metric, 'tol_type':'exp','outfile':"data/HJA.txt", 'verbose':1, 'adapt_t': True, 'mp': True, 'num_proc':20}

# %%
sampler = astroabc.ABC_class(4,100,discharge[0:1500],[10,2],10000,priors,**prop)
# Out:
#
# 	 ########################     astroABC     ########################
#
# 	 Npart=100 	 numt=10000 	 tol=[10.0000,2.0000] exp
# 	 Priors= [('uniform', [2000, 4000]), ('uniform', [0.01, 2]), ('uniform', [0.0001, 0.005]), ('uniform', [0.0001, 0.01])]
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# /home/owani/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:90: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: overflow encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in add
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
# <ipython-input-15-0cd79cf4ecec>:16: RuntimeWarning: overflow encountered in multiply
#   return (par[0]*(1/par[1])*x)
# <ipython-input-17-ba61a106c309>:2: RuntimeWarning: overflow encountered in square
#   return np.sum((d - x)**2)/np.sum((d - np.mean(d))**2)
# <ipython-input-15-0cd79cf4ecec>:15: RuntimeWarning: invalid value encountered in double_scalars
#   x[i + 1] = x[i] -1/par[1]*x[i]*0.1*dt + rain[i]*0.1*dt + (par[2]*x[i]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)

# %%
start = timeit.default_timer()
sampler.sample(sde)
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# 	 Step: 0 	 tol: 10.0 	 Params: [2952.1191730580713, 1.0207580025719396, 0.0024259462280484677, 0.004769981868196325]
# 	 Step: 1 	 tol: 2.0305741480448587 	 Params: [2522.8991766806666, 1.4657343968077878, 0.002754148792759108, 0.004115765800371435]
# 	 Step: 2 	 tol: 2.0 	 Params: [2568.542109574439, 1.3612108290519758, 0.002664346983302784, 0.0039103758229837625]
# Time:  34.81365584800369

# %%
# import  samples
data = ("data/HJA.txt")
samples  =  pd.DataFrame(np.loadtxt('data/HJA.txt', skiprows=1))
samplespar = samples[samples.columns[0:4]]

# %%
# Plot the trace of samples 

samplespar.plot(kind='line', figsize=[30,5], fontsize = 20, title = 'Sample traces')
#samplespar.plot(kind='hist',y ='AMS_cdx', figsize=[30,5], fontsize = 20, title = 'Maximum annual prcipitation')

# %%
fig = sns.pairplot(samplespar)
fig.savefig('images/konza_posterior.jpg',dpi = 150)

# %%
par = [np.asarray(samplespar)[:,0].mean(),np.asarray(samplespar)[:,1].mean(),np.asarray(samplespar)[:,2].mean(),np.asarray(samplespar)[:,3].mean()]
#par = np.array(samplespar)[pd.read_csv(filepath_or_buffer=data, delimiter  =' ',header =0)["\t.1"].idxmax(),:]

# %%
par = np.array(samplespar)[samples[4].idxmin(),:]
par
# Out:
# array([7.43975328e+02, 2.87798000e-01, 5.38400000e-03, 5.94800000e-03])

# %%
n =3000
x = np.zeros([n,500])


dt = 1  # Time step.
T = 3000.  # Total time.
n = int(T / dt)  # Number of time steps.
t = np.linspace(0., T, n)  # Vector of times.


for j in range(499):
    for i in range(n - 1):
        x[i + 1,j] = x[i,j] -1/par[1]*x[i,j]*0.1*dt  + rain[i]*0.1*dt + \
        (par[2]*x[i,j]+par[3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)

sim =  (par[0]*(1/par[1])*x)

# for j in range(499):
#     for i in range(n - 1):
#         x[i + 1,j] = x[i,j] + 1*rain[i]*dt + 0*par[1]*sweb[i]*temp[i]*dt -1/par[0]*x[i,j]*dt + \
#         1*(np.sqrt(par[3])*x[i,j]+np.sqrt(par[4])*rain[i])*np.random.normal(0,np.sqrt(dt),1)+ \
#         np.sqrt(par[5])*np.random.lognormal(0,np.sqrt(dt),1)
# sim = 1/par[0]*par[2]*x

# %%
discharge.shape
# Out:
# (3000,)

# %%
plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots(2,figsize=(18, 12))
fig.suptitle('Rainfall-Storage Modeling', fontsize =30)
fig.subplots_adjust(hspace = 0.4)

ax[0].plot(t, rain, color='blue')
#ax[1].plot(t,sim, color = 'gray')
ax[1].plot(t,sim[:,10], color = 'red')
ax[1].plot(t,discharge, 'k.', markersize = 2 )

#ax[0].set_ylim([0,2])
ax[0].set_xlabel('', fontsize = 25)
ax[0].set_ylabel('rain(t)', fontsize = 25)
ax[0].tick_params(axis='both', which='major', labelsize=18)

#ax[1].set_ylim([0,4])
ax[1].set_xlabel('time (in days)', fontsize = 25)
ax[1].set_ylabel('discharge(t)', fontsize = 25)
#ax[1].set_title('stochastic differential equation: ' r'$dS_t= [r_t-\frac{1}{K}(1+\frac{\beta}{2})S_t]dt+(\sqrt{\frac{\beta}{K}}S_t)dW_t$', fontsize =25)
ax[1].tick_params(axis='both', which='major', labelsize=18)

fig.savefig('images/konza_single.jpg',dpi = 150)

# %%
# With parametric uncertainty

par = np.array(samplespar)[np.random.randint(300,size =200)]
for j in range(199):
    for i in range(n - 1):
        x[i + 1,j] = x[i,j] -1/par[j,1]*x[i,j]*0.1*dt  + rain[i]*0.1*dt + \
        (par[j,2]*x[i,j]+par[j,3]*rain[i])*np.random.normal(0,np.sqrt(0.1*dt),1)
sim =  (par[j,0]*(1/par[j,1])*x)

# %%
plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots(2,figsize=(18, 12))
fig.suptitle('Rainfall-Storage Modeling', fontsize =30)
fig.subplots_adjust(hspace = 0.4)

ax[0].plot(t, rain, color='blue')
ax[1].plot(t,sim, color = 'gray')
ax[1].plot(t,sim.mean(axis=1), color = 'red')
ax[1].plot(t,discharge, 'k.', markersize = 2 )

#ax[0].set_ylim([0,2])
ax[0].set_xlabel('', fontsize = 25)
ax[0].set_ylabel('rain(t)', fontsize = 25)
ax[0].tick_params(axis='both', which='major', labelsize=18)

#ax[1].set_ylim([0,4])
ax[1].set_xlabel('time (t)', fontsize = 25)
ax[1].set_ylabel('discharge(t)', fontsize = 25)
#ax[1].set_title('stochastic differential equation: ' r'$dS_t= [r_t-\frac{1}{K}(1+\frac{\beta}{2})S_t]dt+(\sqrt{\frac{\beta}{K}}S_t)dW_t$', fontsize =25)
ax[1].tick_params(axis='both', which='major', labelsize=18)

#fig.savefig('SDE_test2.jpg',dpi = 150)

# %%
# Make uncertainty intervals

plt.style.use('seaborn-darkgrid')

fig, ax = plt.subplots(2,figsize=(18, 12))
fig.suptitle('Rainfall-Storage Modeling', fontsize =30)
fig.subplots_adjust(hspace = 0.4)

ax[0].plot(t, rain, color='blue')
#ax[1].plot(t,np.percentile(sim, 5, axis=1), color = 'gray')
#ax[1].plot(t,np.percentile(sim, 95, axis=1), color = 'gray')
plt.fill_between(t,np.percentile(sim, 5, axis=1), np.percentile(sim, 95, axis=1), color='gray', alpha=0.5)
#ax[1].plot(t,sim.mean(axis=1), color = 'red')
ax[1].plot(t,discharge, 'k.', markersize = 2 )

#ax[0].set_ylim([0,2])
ax[0].set_xlabel('', fontsize = 25)
ax[0].set_ylabel('rain(t)', fontsize = 25)
plt.axvline(1500 , 0,1000000, color = 'red')
ax[0].tick_params(axis='both', which='major', labelsize=18)

#ax[1].set_ylim([0,4])
ax[1].set_xlabel('time (in days)', fontsize = 25)
ax[1].set_ylabel('discharge(t)', fontsize = 25)
#ax[1].set_title('stochastic differential equation: ' r'$dS_t= [r_t-\frac{1}{K}(1+\frac{\beta}{2})S_t]dt+(\sqrt{\frac{\beta}{K}}S_t)dW_t$', fontsize =25)
ax[1].tick_params(axis='both', which='major', labelsize=18)

plt.text(900, 34000, 'Period of inference', fontsize=15,  color='red')
plt.text(1550, 34000, 'Period of validation', fontsize=15,  color='red')
#annotation
#ax.plot([33.5], [2.5], 'o')
#ax.annotate('peak', xy=(33.5, 2.5), xytext=(40, 4), fontsize=12,
#            arrowprops=dict(facecolor='black', shrink=0.05))

fig.savefig('images/konza.jpg',dpi = 150)

# %% [markdown]
# # Performance

# %%
ci5 = np.percentile(sim, 5, axis=1)
ci95 = np.percentile(sim, 95, axis=1)

n=0
for i in range(1500):
    if  ci5[i] < discharge[i] and ci95[i] > discharge[i]:
        n = n+1

# %%
#Reliability

ci5 = np.percentile(sim, 5, axis=1)
ci95 = np.percentile(sim, 95, axis=1)

n=0
for i in range(1500):
    if  ci5[1500+i] < discharge[1500+i] and ci95[1500+i] > discharge[1500+i]:
        n = n+1

# %%
n/1500*100  

#HJ Andrew
# 63.3 calibration
# 67.8 validation

#Kellog
# 72.66 calibration
# 70.66 validation

#Konza 
#18.33 calibration
# 18.94 validation
# Out:
# 26.666666666666668

# %% [markdown]
# # Generate dynamic plot

# %%
data = sim[:,1] #Generating data.
#plt.figure(figsize = (5,5))
sns.kdeplot(data , bw = 0.5)# , fill = True)
plt.axvline(1 , 0,1, color = 'black')
plt.ylabel('dynamic probability density', fontsize = 15)
plt.xlabel('system response', fontsize = 15)
plt.legend(framealpha=1, frameon=True)
plt.title('HJ Andrews')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt, glob, os
import IPython.display as IPdisplay, matplotlib.font_manager as fm
from scipy.integrate import odeint
from mpl_toolkits.mplot3d.axes3d import Axes3D
from PIL import Image

# %%
# define the fonts to use for plots
family = 'Myriad Pro'
title_font = fm.FontProperties(family=family, style='normal', size=20, weight='normal', stretch='normal')

# %%
save_folder = 'images/dynamicprobability'
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

# %%
def plot_phase(n):
   data = sim[n,:] #Generating data.
   max = (np.histogram(data)[1])[np.argmax((np.histogram(data))[0])]
   plt.figure(figsize = (8,5))
   sns_plot = sns.kdeplot(data , bw = 0.5)# , fill = True)
   #plt.axvline(max, 0,1, color = 'blue')
   plt.axvline(discharge[n], 0,1, color = 'black')
   plt.xlim(0, 1000000)
   plt.ylim(0, (25*10**(-6)))
   plt.ylabel('dynamic probability density', fontsize = 15)
   plt.xlabel('system response', fontsize = 15)
   plt.legend(framealpha=1, frameon=True)
   plt.title('konza')
   plt.savefig('{}/{:03d}.png'.format(save_folder, n), dpi=200, bbox_inches='tight', pad_inches=0.1)
   plt.close()

# %%
def plot_phase(n):
   data = sim[n,:] #Generating data.
   max = (np.histogram(data)[1])[np.argmax((np.histogram(data))[0])]
   plt.figure(figsize = (8,5))
   sns_plot = sns.kdeplot(data , bw = 0.5)# , fill = True)
   #plt.axvline(max, 0,1, color = 'blue')
   plt.axvline(discharge[n], 0,1, color = 'black')
   plt.xlim(0, 10000)
   plt.ylim(0, (10*10**(-3)))
   plt.ylabel('dynamic probability density', fontsize = 15)
   plt.xlabel('system response', fontsize = 15)
   plt.legend(framealpha=1, frameon=True)
   plt.title('konza')
   plt.savefig('{}/{:03d}.png'.format(save_folder, n), dpi=200, bbox_inches='tight', pad_inches=0.1)
   plt.close()

# %%
for n in range(140):
    plot_phase(n)
# Out:
# /home/owani/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# /home/owani/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# load all the static images into a list
save_folder = 'images/dynamicprobability'
images = [Image.open(image) for image in glob.glob('{}/*.png'.format(save_folder))]
gif_filepath = 'images/animated-dynamicprob_HJA.gif'

# %%
# save as an animated gif
gif = images[0]
gif.info['duration'] = 800 #ms per frame
gif.info['loop'] = 0 #how many times to loop (0=infinite)
gif.save(fp=gif_filepath, format='gif', save_all=True, append_images=images[1:],quality=50)

# %%
# verify that the number of frames in the gif equals the number of image files and durations
Image.open(gif_filepath).n_frames == len(images)
# Out:
# True

# %%
#IPdisplay.Image(url=gif_filepath)

# %% [markdown]
# # AndrewsForest
